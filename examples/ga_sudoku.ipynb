# %%
import sys
sys.path.append('..')
import numpy as np
import ga4graphcoloring as ga

# %% [markdown]
# # GA Sudoku Solver
#
# With some minor modifications, we can use the GA to solve Sudoku puzzles.
# But need to modify the mutation function to ensure that the constraints are not violated.
#
# The code works in the following way:
# 1. A completed sudoku puzzle is generated.
# 2. Some cells are randomly cleared to create a puzzle.
# 3. GA is used to solve the puzzle.
#
# ## Sudoku as graphs
#
# The sudoku board can be considered as a 81 node graph with a fixed adjacency matrix.
# The edjes are the constraints that the numbers must satisfy:
# - Each row must have all numbers from 1 to 9
# - Each column must have all numbers from 1 to 9
# - Each 3x3 subgrid must have all numbers from 1 to 9

# %%
# helper functions
def find_solution(sudoku, pop):
    for i in range(1000):
        pop.evolve(elitism=False)
        print(f'Generation {i} best fitness: {pop.best_fitness}')
        if pop.best_fitness == 0:
            break
    sudoku.display(pop.solution)
    return pop.solution

# %%
# create a sudoku puzzle
s = ga.sudoku.Sudoku(difficulty=0.3)
s.display()

# create population
pop = ga.sudoku.SudokuPopulation(200, s)
# Out:
# +---------+---------+---------+
# | 8  2  7 | 6     9 | 1     5 |
# | 6  3  9 |    4  1 | 7  2  8 |
# | 5  4  1 | 8  2  7 | 9  3  6 |
# |---------+---------+---------|
# | 3  9  8 | 4  1  6 | 5       |
# |    1  6 | 2  7  5 |       3 |
# |    7  5 | 3  9    |    1  4 |
# |---------+---------+---------|
# | 7  5  4 |    8  2 | 3  6  1 |
# | 9  8  2 | 1  6  3 | 4  5  7 |
# | 1  6  3 | 7     4 | 2  8  9 |
# +---------+---------+---------+

# %%
# solve the puzzle
sol = find_solution(s, pop)
# Out:
# Generation 0 best fitness: 14
# Generation 1 best fitness: 13
# Generation 2 best fitness: 11
# Generation 3 best fitness: 8
# Generation 4 best fitness: 8
# Generation 5 best fitness: 4
# Generation 6 best fitness: 4
# Generation 7 best fitness: 3
# Generation 8 best fitness: 2
# Generation 9 best fitness: 2
# Generation 10 best fitness: 0
# +---------+---------+---------+
# | 8  2  7 | 6  3  9 | 1  4  5 |
# | 6  3  9 | 5  4  1 | 7  2  8 |
# | 5  4  1 | 8  2  7 | 9  3  6 |
# |---------+---------+---------|
# | 3  9  8 | 4  1  6 | 5  7  2 |
# | 4  1  6 | 2  7  5 | 8  9  3 |
# | 2  7  5 | 3  9  8 | 6  1  4 |
# |---------+---------+---------|
# | 7  5  4 | 9  8  2 | 3  6  1 |
# | 9  8  2 | 1  6  3 | 4  5  7 |
# | 1  6  3 | 7  5  4 | 2  8  9 |
# +---------+---------+---------+

# %% [markdown]
# ## Manually creating a sudoku
#
# We can also manually create a sudoku puzzle and solve it. To do this we must set `difficilty` to 0 to ensure that no numbers are removed.
# More difficult sudokus require a greater number of individuals to preserve diversity of solution and avoid local minima.

# %%
sudoku_mat = np.array([
    [0,5,0,6,7,0,0,0,0],
    [6,3,0,0,4,0,1,0,0],
    [0,0,0,0,3,0,0,0,8],
    [1,2,3,0,0,7,0,0,0],
# Generation 285 best fitness: 6
# Generation 286 best fitness: 6
# Generation 287 best fitness: 6
# Generation 288 best fitness: 6
# Generation 289 best fitness: 6
# Generation 290 best fitness: 6
# Generation 291 best fitness: 6
# Generation 292 best fitness: 6
# Generation 293 best fitness: 6
# Generation 294 best fitness: 6
# Generation 295 best fitness: 6
# Generation 296 best fitness: 6
# Generation 297 best fitness: 6
# Generation 298 best fitness: 6
# Generation 299 best fitness: 6
# Generation 300 best fitness: 6
# Generation 301 best fitness: 6
# Generation 302 best fitness: 6
# Generation 303 best fitness: 6
# Generation 304 best fitness: 6
# Generation 305 best fitness: 6
# Generation 306 best fitness: 6
# Generation 307 best fitness: 6
# Generation 308 best fitness: 6
# Generation 309 best fitness: 6
# Generation 310 best fitness: 6
# Generation 311 best fitness: 6
# Generation 312 best fitness: 6
# Generation 313 best fitness: 6
# Generation 314 best fitness: 6
# Generation 315 best fitness: 6
# Generation 316 best fitness: 6
# Generation 317 best fitness: 6
# Generation 318 best fitness: 6
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 16
#      13 s = ga.sudoku.Sudoku(difficulty=0, solution=sudoku_mat)
#      14 pop = ga.sudoku.SudokuPopulation(2000, s)
# ---> 16 sol = find_solution(s, pop)
#
# Cell In[2], line 4, in find_solution(sudoku, pop)
#       2 def find_solution(sudoku, pop):
#       3     for i in range(1000):
# ----> 4         pop.evolve(elitism=False)
#       5         print(f'Generation {i} best fitness: {pop.best_fitness}')
#       6         if pop.best_fitness == 0:
#
# File ~/Scratch/GA4GraphColoring/ga4graphcoloring/gen_algs.py:144, in Population.evolve(self, mutation_rate, tournament_size, elitism)
#     140     new_population.extend(elites)
#     142 while len(new_population) < self.pop_size:
#     143     # select parents with tournament selection
# --> 144     parent1 = self.selection(tournament_size)
#     145     parent2 = self.selection(tournament_size)
#     147     # crossover the parents to produce a child and mutate it
#
# File ~/Scratch/GA4GraphColoring/ga4graphcoloring/gen_algs.py:116, in Population.selection(self, tournament_size)
#     114 # tournament = np.random.choice(self.individuals, size=tournament_size, replace=False)
#     115 tournament = random.choices(self.individuals, k=tournament_size)
# --> 116 fitness_scores = [self.fitness(individual) for individual in tournament]
#     117 return tournament[np.argmin(fitness_scores)]
#
# File ~/Scratch/GA4GraphColoring/ga4graphcoloring/gen_algs.py:116, in <listcomp>(.0)
#     114 # tournament = np.random.choice(self.individuals, size=tournament_size, replace=False)
#     115 tournament = random.choices(self.individuals, k=tournament_size)
# --> 116 fitness_scores = [self.fitness(individual) for individual in tournament]
#     117 return tournament[np.argmin(fitness_scores)]
#
# File ~/Scratch/GA4GraphColoring/ga4graphcoloring/gen_algs.py, in Population.fitness(self, individual)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# KeyboardInterrupt:

# %% [markdown]
# ## Conclusions
#
# After 318 generation (49 minutes on my laptop), no solution is found.
# This is consistent with results found in literature when imposing no constraints on the individuals of the population.
#
# We can conclude that the GA algorithm adapted from the graph coloting problem is not suitable for solving sudoku puzzles.
